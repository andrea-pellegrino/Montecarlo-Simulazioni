# %%
import pandas as pd
import numpy as np

#Squadre = ['Atalanta','Bologna','Brescia','Cagliari','Fiorentina',
#          'Genoa','Hellas Verona','Inter','Juventus','Lazio',
#          'Lecce','Milan','Napoli','Parma','Roma',
#          'Sampdoria','Sassuolo','SPAL','Torino','Udinese']

Squadre = ["Valle d'Aosta",'Piemonte','Liguria','Lombardia','Veneto',
           'Trentino-Alto Adige','Friuli-Venezia Giulia','Emilia-Romagna','Toscana','Marche',
           'Umbria','Lazio','Abruzzo','Molise','Campania',
           'Puglia','Basilicata','Calabria','Sicilia','Sardegna']

Numero_Squadre = len(Squadre)
Flag = 0
Obiettivo = 'Calabria'
while Flag == 0:
    #Val = [3,4,5,4,4,
    #       5,4,2,1,2,
    #       5,3,2,4,3,
    #       5,5,5,4,5]
    Val = [7,3,4,1,3,
           5,4,2,2,4,
           4,1,4,6,1,
           3,5,4,3,4]

    Valori = np.zeros(Numero_Squadre)

    Flag = 0
    for k in range(Numero_Squadre):
        randomNums = np.random.normal(scale=1.5, size=1)
        randomInts = np.round(randomNums)
        dl = np.int(np.abs(randomInts))
        Valori[k] = np.random.randint(Val[k]-dl,Val[k]+dl+1, dtype='int')

    Valori = Valori.astype(int)

    Classifica = np.zeros(Numero_Squadre)
    Vittorie = np.zeros(Numero_Squadre)
    Pareggi = np.zeros(Numero_Squadre)
    Sconfitte = np.zeros(Numero_Squadre)

    Forza = pd.DataFrame({'Squadre':Squadre,'Valori':Valori,'Classifica':Classifica,'V':Vittorie,'P':Pareggi,'S':Sconfitte})

    df = pd.DataFrame(np.zeros((Numero_Squadre,Numero_Squadre)), columns = np.arange(0,Numero_Squadre))

    # 0 = Sconfitta
    # 1 = Pareggio
    # 3 = Vittoria

    # Riga = in casa
    # Colonna = fuori casa
    # in casella c'è sempre il valore del risultato per la squadra in casa

    for i in range(0,Numero_Squadre):
        Val_C = Forza.iloc[i]['Valori']
        for j in range(0,Numero_Squadre):
            Val_F = Forza.iloc[j]['Valori']
            Result = np.random.rand()

            if i == j:
                df.iloc[i][j] = np.nan

            elif Val_C - Val_F <= -5:
                SogliaW = 0.95
                SogliaX = 0.98

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == -4:
                SogliaW = 0.9
                SogliaX = 0.95

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == -3:
                SogliaW = 0.8
                SogliaX = 0.9

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == -2:
                SogliaW = 0.7
                SogliaX = 0.85

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == -1:
                SogliaW = 0.6
                SogliaX = 0.85

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1   

            elif Val_C - Val_F == 0:
                SogliaW = 0.5
                SogliaX = 0.8

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == 1:
                SogliaW = 0.4
                SogliaX = 0.65

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1


            elif Val_C - Val_F == 2:
                SogliaW = 0.25
                SogliaX = 0.5

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == 3:
                SogliaW = 0.15
                SogliaX = 0.35

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F == 4:
                SogliaW = 0.1
                SogliaX = 0.2

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            elif Val_C - Val_F >= 5:
                SogliaW = 0.05
                SogliaX = 0.1

                if Result > SogliaX:
                    df.iloc[i][j] = 0
                    Forza.loc[j,'Classifica'] += 3
                    Forza.loc[i,'S'] += 1
                    Forza.loc[j,'V'] += 1
                elif Result > SogliaW:
                    df.iloc[i][j] = 1
                    Forza.loc[i,'Classifica'] += 1
                    Forza.loc[j,'Classifica'] += 1
                    Forza.loc[i,'P'] += 1
                    Forza.loc[j,'P'] += 1
                else:
                    df.iloc[i][j] = 3
                    Forza.loc[i,'Classifica'] += 3
                    Forza.loc[i,'V'] += 1
                    Forza.loc[j,'S'] += 1

            else:
                print('ERRORE!')

    Forza = Forza.sort_values(by=['Classifica'], ascending=False).reset_index(drop=True)
    Forza.index = Forza.index + 1
    Forza['Classifica']=pd.to_numeric(Forza['Classifica'], downcast='integer')
    Forza['V']=pd.to_numeric(Forza['V'], downcast='integer')
    Forza['P']=pd.to_numeric(Forza['P'], downcast='integer')
    Forza['S']=pd.to_numeric(Forza['S'], downcast='integer')
    #print(Forza[['Squadre','Classifica','V','P','S']])
    df.index = Squadre
    df.columns = Squadre
    if (Forza[Forza.index == 1]['Squadre']).any() == Obiettivo:
        Flag = 1
        Forza = Forza.drop('Valori', axis=1)
        print(Forza)

# %%
df
